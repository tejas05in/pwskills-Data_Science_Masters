# %%
# Basic structures in python

# %% [markdown]
# ## Logical Operators
# 1. And
# 2. Or
# 3. Not

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not bool(0)
# Out:
# True

# %%
not int(bool(0))
# Out:
# True

# %%
not int(bool(1))
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
not 2
# Out:
# False

# %%
not (not 2)
# Out:
# True

# %%
not -1
# Out:
# False

# %%
bool(0.99)
# Out:
# True

# %% [markdown]
# ## Logical And

# %%
True * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
not (False) * True
# Out:
# True

# %%
False * (not(False))
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
(not (True)) * False
# Out:
# 0

# %%
(not(False)) * False
# Out:
# 0

# %%
(1+2)*3
# Out:
# 9

# %%
False * True
# Out:
# 0

# %%
not 0
# Out:
# True

# %%
lst_a = [1,2,3,4]
lst_b = [1,2,3,4]

lst_a == lst_b
# Out:
# True

# %%
lst_a is not lst_b
# Out:
# True

# %%
print(id(lst_a))
print(id(lst_b))
# Out:
# 1654392006464
# 1654392046720

# %%
lst_a is lst_b
# Out:
# False

# %%
lst_b = lst_a

# %%
print(id(lst_a))
print(id(lst_b))
# Out:
# 1654392006464
# 1654392006464

# %%
lst_a is lst_b
# Out:
# True

# %%
lst_a = [1,2,3,4]
lst_b = [1,2,3,4]

lst_b is not lst_a
# Out:
# True

# %%
lst_a == lst_b
# Out:
# True

# %%
a = 2
b = 2

# %%
print(id(a))
print(id(b))
# Out:
# 1654294014288
# 1654294014288

# %%
str1 = 'Tejas'
str2 = 'Tejas'
print(id(str1))
print(id(str2))
# Out:
# 1654392107312
# 1654392107312

# %%
str1 = 'Tejas'
str2 = 'Tejas1'
print(id(str1))
print(id(str2))
# Out:
# 1654392107312
# 1654392024048

# %%
lst_a[0] = 10

# %%
lst_a
# Out:
# [10, 2, 3, 4]

# %%
str1
# Out:
# 'Tejas'

# %%
str1[0] = 'n' ## immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2928\3333261426.py in <module>
# ----> 1 str1[0] = 'n' ## immutable
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Comparison Operations

# %% [markdown]
# ## Arithmetic Operations

# %%
a = 25
b = 101

# %%
b*a
# Out:
# 2525

# %%
b+a
# Out:
# 126

# %%
a/b
# Out:
# 0.24752475247524752

# %%
a//b
# Out:
# 0

# %%
b//a
# Out:
# 4

# %%
b/a
# Out:
# 4.04

# %%
b%a
# Out:
# 1

# %%
a%b
# Out:
# 25

# %% [markdown]
# #bitwise operation

# %%
var=(10)
bin(var)
# Out:
# '0b1010'

# %%
~var
# Out:
# -11

# %%
bin(~var)
# Out:
# '-0b1011'

# %%
True & False
# Out:
# False

# %%
True | False
# Out:
# True

# %%
var
# Out:
# 10

# %%
var >> 1
# Out:
# 5

# %%
var << 1
# Out:
# 20

# %% [markdown]
# # Strings

# %%
"Welcome to Data Science Masters"
# Out:
# 'Welcome to Data Science Masters'

# %%
str1 = "Welcome to Data Science Masters"

# %%
type(str1)
# Out:
# str

# %%
#immutable
str1[0] =12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2928\2984138468.py in <module>
#       1 #immutable
# ----> 2 str1[0] =12
#
# TypeError: 'str' object does not support item assignment

# %%
str1 = 'Tejas J'

# %%
str1
# Out:
# 'Tejas J'

# %%
str1.upper()
# Out:
# 'TEJAS J'

# %%
welcome = 'Hello World'

# %%
welcome.count('c')
# Out:
# 0

# %%
dir(welcome)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
string = 'Pw Skills Data Science'

# %%
#slice operation
string[5:11]
# Out:
# 'ills D'

# %%
string[-1]
# Out:
# 'e'

# %%
string[7:5]
# Out:
# ''

# %%
string[-7:5:-1]
# Out:
# 'S ataD sll'

# %%
string[:-1]
# Out:
# 'Pw Skills Data Scienc'

# %%
string[:]
# Out:
# 'Pw Skills Data Science'

# %%
name = 'Karthik'
name[-5:4]
# Out:
# 'rt'

# %%
string[::-2]
# Out:
# 'eniSaa liSw'

# %%
string[::-1]
# Out:
# 'ecneicS ataD sllikS wP'

# %%
string
# Out:
# 'Pw Skills Data Science'

# %%
string[6:3:-1]
# Out:
# 'lik'

# %%
string[::5]
# Out:
# 'PiDSc'

# %%
name
# Out:
# 'Karthik'

# %%
name[3::-1]
# Out:
# 'traK'

# %%
name = 'Tejas Naidu'

# %%
name[3:1:-1]
# Out:
# 'aj'

# %%
course_name = "Data Science Masters"

# %%
course_name[5:12]
# Out:
# 'Science'

# %%
course_name[-9:-17:-1]
# Out:
# 'ecneicS '

# %%
course_name[11:4:-1]
# Out:
# 'ecneicS'

# %%
course_name[11]
# Out:
# 'e'

# %%
course_name + "Course"
# Out:
# 'Data Science MastersCourse'

# %%
print('Hello' + 'Worlds')
# Out:
# HelloWorlds

# %%
course_name*5
# Out:
# 'Data Science MastersData Science MastersData Science MastersData Science MastersData Science Masters'

# %%
len(course_name)
# Out:
# 20

# %%
# find function
course_name.find('n')
# Out:
# 9

# %%
course_name.find('a',2,10)
# Out:
# 3

# %%
#error is returned as -1
course_name.find('z')
# Out:
# -1

# %%
## count
course_name.count('a')
# Out:
# 3

# %%
course_name.count(' ')
# Out:
# 2

# %%
course_name.count('')
# Out:
# 21

# %%
course_name.count('a',2,10)
# Out:
# 1

# %%
course_name
# Out:
# 'Data Science Masters'

# %%
# sting split function

# %%
course_name.split()
# Out:
# ['Data', 'Science', 'Masters']

# %%
course_name.split('S')
# Out:
# ['Data ', 'cience Masters']

# %%
course_name.split('s')
# Out:
# ['Data Science Ma', 'ter', '']

# %%
course_name.partition('s')
# Out:
# ('Data Science Ma', 's', 'ters')

# %%
### string upper and lower

# %%
course_name.upper()
# Out:
# 'DATA SCIENCE MASTERS'

# %%
course_name.lower()
# Out:
# 'data science masters'

# %%
course_name.capitalize()
# Out:
# 'Data science masters'

# %%
course_name.casefold()
# Out:
# 'data science masters'

# %%
course_name.swapcase()
# Out:
# 'dATA sCIENCE mASTERS'

# %%
course_name.title()
# Out:
# 'Data Science Masters'

# %%
len(course_name)
# Out:
# 20

# %%
course_name.count('')

# %%
import pandas as pd
