# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")


p = figure(title = "test flower")

p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"

p.circle(flowers["petal_length"],flowers["petal_width"])
show(p)
# Out:
#   <div class="bk-root" id="62c75309-1739-4288-8685-6098b590d683" data-root-id="1003"></div>

# %%
output_file("test.html")


p = figure(title = "test flower")

p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"

p.line(flowers["petal_length"],flowers["petal_width"])
show(p)
# Out:
#   <div class="bk-root" id="63e7b401-fc70-43c3-8850-e00dce4661d0" data-root-id="1223"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title="line graph")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="f0d48b89-1e72-4b94-876e-bbc59125cb50" data-root-id="1473"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title="line graph")
p.scatter(x,y,size=20,fill_color="red",legend_label = "this is my data points")
show(p)
# Out:
#   <div class="bk-root" id="f010d8d8-5f06-43a6-9f77-5fa720b24a3c" data-root-id="2573"></div>
